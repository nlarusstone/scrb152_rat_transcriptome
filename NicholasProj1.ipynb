# %%
import pandas as pd
import rpy2
import readline
import numpy as np
from scipy import stats as scistats
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import re

# %matplotlib inline

# %load_ext rpy2.ipython

# %%
def prettify_ax(ax):
    """
    Nifty function we can use to make our axes more pleasant to look at
    """
    for spine in ax.spines.itervalues():
        spine.set_visible(False)
    ax.set_frameon=True
    ax.patch.set_facecolor('#eeeeef')
    ax.grid('on', color='w', linestyle='-', linewidth=1)
    ax.tick_params(direction='out')
    ax.set_axisbelow(True)
    
def simple_ax(figsize=(6,4), **kwargs):
    """
    Shortcut to make and 'prettify' a simple figure with 1 axis
    """
    fig = plt.figure(figsize=figsize)
    ax = fig.add_subplot(111, **kwargs)
    prettify_ax(ax)
    return fig, ax

# %% [markdown]
# # Counts -> TMM Normalized cpm

# %%
def log_cpm(counts, libraries):
    log_counts = pd.DataFrame()
    for col in counts:
        #R_col = sum(counts[col])
        #R_eff_coll = R_col * libraries.ix[col, 'norm.factors']
        #counts[col] = counts[col].apply(lambda x: (x + 0.5) / ((R_col + 1.0) / (10 ** 6)))
        #counts[col] = counts[col].apply(lambda x: np.log2(x))
        R_eff = libs.ix[col, 'effective.lib.size']
        log_counts[col] = np.log2(1e6*(counts[col]+0.5)/(R_eff + 1))
    return log_counts

def tmm_norm(mat):
    # %Rpush mat
    # %R library(edgeR)
    # %R library(limma)
    # %R myDGEList <- DGEList(counts=mat)
    # %R x <- calcNormFactors(myDGEList)
    # %R calcNormFactorsResults <- x[['samples']]
    # %R rowNames <- rownames(calcNormFactorsResults)
    # %Rpull calcNormFactorsResults
    # %Rpull rowNames
    libraries = calcNormFactorsResults.set_index(rowNames)
    libraries['effective.lib.size'] = libraries['lib.size'] * libraries['norm.factors']
    return libraries

# %% [markdown]
# # PCA

# %%
def project(mean_centered, num_pcs):
    XTX = (1.0 / len(mean_centered.T)) * mean_centered.T.dot(mean_centered)
    evals, evecs = np.linalg.eigh(XTX)
    indices = (-evals).argsort()
    D = np.diag(evals[indices])
    V = []
    for ev in evecs:
        V.append(ev[indices])
    V = np.array(V)
    D_R = D[:num_pcs, :num_pcs] ** (-0.5)
    D_R[D_R == np.inf] = 0
    SVD = np.sqrt(1.0 / len(mean_centered.T)) * mean_centered.dot(V[:, :num_pcs].dot(D_R))
    P = np.array(SVD.T.dot(mean_centered))
    return evals, P, indices

def plot_pcs(P, idx1, idx2, c=None):
    fig, ax = simple_ax(figsize=(6,6))
    ax.scatter(P[idx1], P[idx2], c=c, s=100, edgecolor='w')

    ax.set_title('PC1 vs PC2')
    ax.set_xlabel('Principal Component ' + str(idx1 + 1))
    ax.set_ylabel('Principal Component ' + str(idx2 + 1))
    
def plot_var(eigenvalues, indices, xlim):
    tot_var = eigenvalues[indices].sum()
    pc_vars = eigenvalues[indices] / tot_var

    fig, ax = simple_ax(figsize=(6,6))
    ax.plot(pc_vars, 'o-')
    ax.set_xlim([1, xlim])
    ax.set_xticks(range(xlim))
    ax.set_xticklabels(range(1, xlim))

    ax.set_title('Percentage of variance captured by Principal Components')
    ax.set_xlabel('Principal Component')
    ax.set_ylabel('Percentage of variance captured')

# %% [markdown]
# # Clustering

# %%
import fastcluster
from sklearn import cluster, datasets
import scipy.cluster.hierarchy as hier
import matplotlib.colors as mcolors

def linkage(mat):
    gene_link = fastcluster.linkage(mat, method='ward', metric='correlation')
    cell_link = fastcluster.linkage(mat.T, method='ward', metric='correlation')

    gene_order = hier.leaves_list(gene_link)
    cell_order = hier.leaves_list(cell_link)

    reordered_data_subset = mat.values[gene_order, :]
    reordered_data_subset = reordered_data_subset[:, cell_order]
    #reordered_data_subset = log2_cpm.ix[gene_order, cell_order]
    return gene_link, cell_link, reordered_data_subset

# From: http://stackoverflow.com/questions/16834861/create-own-colormap-using-matplotlib-and-plot-color-scale
def make_colormap(seq):
    """Return a LinearSegmentedColormap
    seq: a sequence of floats and RGB-tuples. The floats should be increasing
    and in the interval (0,1).
    """
    seq = [(None,) * 3, 0.0] + list(seq) + [1.0, (None,) * 3]
    cdict = {'red': [], 'green': [], 'blue': []}
    for i, item in enumerate(seq):
        if isinstance(item, float):
            r1, g1, b1 = seq[i - 1]
            r2, g2, b2 = seq[i + 1]
            cdict['red'].append([item, r1, r2])
            cdict['green'].append([item, g1, g2])
            cdict['blue'].append([item, b1, b2])
    return mcolors.LinearSegmentedColormap('CustomMap', cdict)

def heatmap(gene_link, cell_link, reordered_data_subset):
    fig = plt.figure(figsize=(16, 8), dpi=96)
    from matplotlib import gridspec
    gs = gridspec.GridSpec(2, 2,
                           width_ratios=[1,10],
                           height_ratios=[1,10],
                           wspace=0.05,
                           hspace=0.05)


    # # x ywidth height
    ax1 = fig.add_subplot(gs[0,1], frameon=False)
    Z1 = hier.dendrogram(cell_link, orientation='top', ax=ax1) # adding/removing the axes
    ax1.set_xticks([])
    ax1.set_yticks([])

    ax2 = fig.add_subplot(gs[1,0], frameon=False)
    Z2 = hier.dendrogram(gene_link, orientation='left', ax=ax2) # adding/removing the axes
    ax2.set_xticks([])
    ax2.set_yticks([])

    axmatrix = fig.add_subplot(gs[1,1])
    # norm=mpl.colors.Normalize(vmin=0, vmax=40)
    c = mcolors.ColorConverter().to_rgb
    gbr = make_colormap(
            [c('black'), c('green'), 0.33, c('green'), c('red'), 0.66, c('red')])
    im = axmatrix.matshow(reordered_data_subset.T, aspect='auto', origin='lower', cmap=gbr, interpolation='none')
    axmatrix.set_xticks([])
    axmatrix.set_yticks([])

# %%
full_count = pd.read_csv('/n/regal/scrb152/Data/Yu_et_al/full_counts_matrix.csv')
fullCounts = full_count.iloc[:, 1:]
# Remove rows with all 0 counts
filtered_fullCounts = fullCounts.loc[(fullCounts!=0).any(axis=1)]
full_count.rename(columns={"Unnamed: 0": "Gene_id"}, inplace=True)
full_count.set_index('Gene_id', inplace=True)
genes = full_count.index
full_count
# Out:
#                 Adr_F_002_1  Adr_F_002_2  Adr_F_002_3  Adr_F_002_4  \
# Gene_id
# Vom2r3                    4            3            1            2
# LOC100909608              0            0            0            1
# Vom2r6                   27           33           36           34
# Vom2r5                    0            0            4            1
# Raet1l                    0            2            2            7
# ...                     ...          ...          ...          ...
# AABR07022580.1            0            0            0            0
# AABR07022882.1            0            0            0            0
# Nkrfl                    53           45           47           50
# AABR07022739.1            7            4            5            8
# AABR07022999.1            0            0            0            0
# AABR07022469.1           37           43           26           26
# AABR07022470.1            0            0            0            0
# AABR07022903.1            0            0            0            0
# LOC100910896              0            0            0            0
# LOC100910181              0            0            0            0
# AABR07022393.1           25           24           19           20
# AABR07022735.1            0            1            0            0
# AABR07022309.1            0            0            0            0
# AABR07022624.1            0            0            0            0
# AABR07023023.1            0            0            0            0
# LOC100911695              0            0            0            0
# AABR07024399.1            0            0            0            0
# AABR07022731.1            0            0            0            0
# AABR07022331.1            0            0            0            0
# AABR07022690.1            0            0            0            0
# AABR07022620.1            0            0            0            0
# AABR07022674.1            0            0            0            0
# AABR07022763.1            0            0            0            0
# AABR07022303.1            0            0            0            0
# AABR07022369.1            0            0            1            0
# AABR07022926.1            0            0            0            0
# AABR07046563.1            0            2            0            0
# LOC100910067             16           13           18           11
# AABR07045682.1            0            0            0            0
# AABR07046248.1            0            0            0            0
#
#                 Adr_F_021_1  Adr_F_021_2     ...       Utr_F_006_3  \
# Gene_id                                      ...
# Vom2r3                    4            7     ...                 0
# LOC100909608              0            1     ...                 0
# Vom2r6                   49           57     ...                 0
# Vom2r5                    6            6     ...                 0
# Raet1l                    7            1     ...                 2
# AABR07000109.1            0            0     ...                 1
# AABR07000121.1           62           80     ...               343
# AABR07000137.1            0            2     ...                 4
# AABR07000145.1            1            0     ...                 2
# Raet1d                   13            4     ...                10
# AABR07000156.1           80          100     ...                95
# LOC679782                 2            0     ...                 3
# AABR07000158.1            0            0     ...                 0
# AABR07000159.4            0            1     ...                 1
# Lrp11                   957         1213     ...               405
# AABR07000159.1            5            6     ...                 2
# Pcmt1                   561          696     ...               524
# Nup43                   276          301     ...               259
# Lats1                  3116         3001     ...              2236
# Katna1                  342          364     ...               361
# Ginm1                  4464         5080     ...               924
# AABR07000159.3            0            1     ...                 0
# AABR07000159.2            1            0     ...                 1
# Ppil4                   757          684     ...               776
# Zc3h12d                  36           54     ...               154
# Tab2                   1056         1314     ...              1644
# Ust                      62           78     ...                80
# AABR07000171.1            0            0     ...                 0
# AABR07000173.1            0            0     ...                 0
# Sash1                   979         1325     ...              4743
# ...                     ...          ...     ...               ...
# AABR07022580.1            0            0     ...                 0
# AABR07022882.1            0            0     ...                 0
# Nkrfl                    76           68     ...                66
# AABR07022739.1            5            7     ...                 3
# AABR07022999.1            0            1     ...                 0
# AABR07022469.1           39           54     ...                12
# AABR07022470.1            0            1     ...                 0
# AABR07022903.1            0            0     ...                 0
# LOC100910896              0            0     ...                 0
# LOC100910181              0            0     ...                 0
# AABR07022393.1           14           29     ...                 6
# AABR07022735.1            0            6     ...                 0
# AABR07022309.1            0            2     ...                 0
# AABR07022624.1            0            0     ...                 0
# AABR07023023.1            0            0     ...                 0
# LOC100911695              0            0     ...                 0
# AABR07024399.1            0            0     ...                 0
# AABR07022731.1            0            0     ...                 0
# AABR07022331.1            0            0     ...                 0
# AABR07022303.1            0
# AABR07022369.1            0
# AABR07022926.1            0
# AABR07046563.1            0
# LOC100910067             19
# AABR07045682.1            0
# AABR07046248.1            0
#
# [32140 rows x 320 columns]

# %%
full_count_lib = tmm_norm(full_count)
log_full_count = log_cpm(full_count, fulL_count_lib)

# %%
GO_df = pd.read_csv('./data/gene_association.rgd', sep='\t', skiprows=26, 
            names=['DB Object ID', 'DB Object Symbol', 'Qualifier', 'GO ID', 'DB:Reference', 'Evidence Code', 
                     'With or From', 'Aspect', 'DB Object Name', 'DB Object Synonym', 'DB Object Type', 'Taxon', 
                     'Date', 'Assigned By', 'Gene Product Form ID', 'NA'])
# Out:
# /n/scrb152/Software/Python/pyscrb152/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (1,10,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
genes
# Out:
# Index([u'Vom2r3', u'LOC100909608', u'Vom2r6', u'Vom2r5', u'Raet1l',
#        u'AABR07000109.1', u'AABR07000121.1', u'AABR07000137.1',
#        u'AABR07000145.1', u'Raet1d',
#        ...
#        u'AABR07022620.1', u'AABR07022674.1', u'AABR07022763.1',
#        u'AABR07022303.1', u'AABR07022369.1', u'AABR07022926.1',
#        u'AABR07046563.1', u'LOC100910067', u'AABR07045682.1',
#        u'AABR07046248.1'],
#       dtype='object', name=u'Gene_id', length=32140)

# %%
from collections import defaultdict
GO_dict = defaultdict(list)
for gene in genes:
    GOs = GO_df[GO_df['DB Object Symbol'] == gene]
    #unique_ids = GOs['GO ID'].unique()
    #GO_dict.update(zip(unique_ids, [gene] * len(unique_ids)))
    #if gene == 'Vom2r5':
    #    break
    for key, GO in GOs.iterrows():
        if not (gene in GO_dict[GO['GO ID']]):
            GO_dict[GO['GO ID']].append(gene)
GO_dict

# %%
import pickle
pickle.dump(GO_dict, 'GO_dict')

# %%
from collections import Counter
def genes_to_GO_IDs(GO_df, genes):
    GO_IDs = Counter()
    for g in genes:
        GOs = GO_df[GO_df['DB Object Symbol'] == g]
        GO_IDs.update(list(GOs['GO ID'].unique()))
    return GO_IDs
genes_to_GO_IDs(GO_df, ['Trpv5'])
# Out:
# Counter({'GO:0005262': 1,
#          'GO:0005516': 1,
#          'GO:0005887': 1,
#          'GO:0006816': 1,
#          'GO:0016324': 1,
#          'GO:0031226': 1,
#          'GO:0035809': 1,
#          'GO:0046872': 1,
#          'GO:0051262': 1,
#          'GO:0055074': 1,
#          'GO:0060402': 1,
#          'GO:0070588': 1,
#          'GO:1990035': 1})

# %%
mean_centered_full_counts = (full_count.T - full_count.mean(1)).T
cov_full_counts =(1./len(full_count.T))*mean_centered_full_counts.dot(mean_centered_full_counts.T)
cov_full_counts
# Out:
# Gene_id             Vom2r3  LOC100909608       Vom2r6      Vom2r5  \
# Gene_id
# Vom2r3            8.993398      0.861367    19.656621    1.427187
# LOC100909608      0.861367      0.532461     3.739043    0.242813
# Vom2r6           19.656621      3.739043   340.558115   11.286406
# Vom2r5            1.427187      0.242813    11.286406    1.060000
# Raet1l           -1.963320     -0.410977   -11.868926   -0.674062
# AABR07000109.1   -0.134082     -0.006348    -0.889893   -0.024219
# AABR07000159.3       -0.002051       -0.006631
# AABR07000159.2        0.017187        0.015781
# Ppil4                 3.573828        0.320586
# Zc3h12d              13.807520       -0.374854
# Tab2                 10.706152        0.718955
# Ust                   1.413477       -0.724238
# AABR07000171.1        0.001660       -0.001611
# AABR07000173.1        0.042578        0.026211
# Sash1                13.787988        2.899912
# ...                        ...             ...
# AABR07022580.1        0.002539        0.002168
# AABR07022882.1        0.000000        0.000000
# Nkrfl                -0.110059       -0.509502
# AABR07022739.1       -0.000195        0.046660
# AABR07022999.1        0.009863       -0.003213
# AABR07022469.1       -0.063184        0.281123
# AABR07022470.1       -0.000391       -0.000430
# AABR07022903.1       -0.000586        0.005605
# LOC100910896         -0.001562        0.001406
# LOC100910181          0.002344       -0.042109
# AABR07022393.1       -0.053320        0.205410
# AABR07022735.1        0.006445       -0.006973
# AABR07022309.1        0.000879        0.000654
# AABR07022624.1        0.004199        0.000869
# AABR07023023.1       -0.000098       -0.000107
# LOC100911695         -0.000488       -0.000537
# AABR07024399.1       -0.006445        0.005410
# AABR07022731.1       -0.000098       -0.000107
# AABR07022331.1       -0.000098        0.003018
# AABR07022690.1        0.000000        0.000000
# AABR07022620.1        0.001855        0.001729
# AABR07022674.1       -0.000195       -0.000215
# AABR07022763.1        0.002246       -0.000967
# AABR07022303.1        0.000000        0.000000
# AABR07022369.1        0.000879       -0.005908
# AABR07022926.1        0.001660       -0.001611
# AABR07046563.1        0.001660       -0.033799
# LOC100910067          0.007715        0.266299
# AABR07045682.1        0.030273        0.002051
# AABR07046248.1        0.002051        0.033193
#
# [32140 rows x 32140 columns]

# %%
agg = {}
samples = list(full_count.columns)
for i in range(len(samples)/4):
    for s in samples[i*4:i*4+4]:
        agg[s] = samples[i * 4]
summarized = full_count.groupby(agg, axis=1).mean()
summarized.head()
# Out:
#               Adr_F_002_1  Adr_F_006_1  Adr_F_021_1  Adr_F_104_1  Adr_M_002_1  \
# Gene_id
# Vom2r3               2.50         3.00         4.25         4.50          3.5
# LOC100909608         0.25         0.25         0.25         0.25          1.5
# Vom2r6              32.50        63.50        37.75        46.50         36.5
# Vom2r5               1.25         2.25         3.50         1.50          1.5
# Raet1l               2.75         3.75         3.00         1.75          3.0
#
#               Adr_M_006_1  Adr_M_021_1  Adr_M_104_1  Brn_F_002_1  Brn_F_006_1  \
# Gene_id
# Vom2r3               4.75         1.50         3.00         1.25         0.75
# LOC100909608         0.75         0.50         1.25         0.25         0.25
# Vom2r6              25.00        22.75        23.25         0.75         1.00
# Vom2r5               1.50         0.75         1.25         0.00         0.00
# Raet1l               4.25         1.50         2.75         1.75         1.00
#
#                  ...       Thm_M_021_1  Thm_M_104_1  Tst_M_002_1  Tst_M_006_1  \
# Gene_id          ...
# Vom2r3           ...              0.50         1.25         7.75         5.25
# LOC100909608     ...              0.50         0.25         1.50         0.75
# Vom2r6           ...              0.25         0.25       123.00        16.75
# Vom2r5           ...              0.50         0.25         3.25         2.25
# Raet1l           ...             10.00        12.00         6.00         5.00
#
#               Tst_M_021_1  Tst_M_104_1  Utr_F_002_1  Utr_F_006_1  Utr_F_021_1  \
# Gene_id
# Vom2r3               8.75        11.00         1.75         1.00         1.75
# LOC100909608         3.50         0.50         0.00         0.00         0.00
# Vom2r6               8.25         5.25         6.00         0.50         0.25
# Vom2r5               3.00         1.50         0.25         0.25         0.00
# Raet1l               3.25         2.75         1.50         2.25         5.50
#
#               Utr_F_104_1
# Gene_id
# Vom2r3               0.50
# LOC100909608         0.25
# Vom2r6               1.00
# Vom2r5               0.25
# Raet1l               4.25
#
# [5 rows x 80 columns]

# %%
#for GO, gene_list in GO_dict:
#    
#    break
from collections import defaultdict
GO = 'GO:0030674'
gene_list = GO_dict[GO]
#print gene_list
not_in_set = [str(g) for g in full_count.index.values if g not in gene_list]
T = defaultdict(list)
not_T = defaultdict(list)
for t in gene_list:
    for in_T in gene_list:
        if t == in_T:
            continue
        T[gene].append(scistats.pearsonr(full_count.ix[t], full_count.ix[in_T]))
    for not_in_T in not_in_set:
        not_T[gene].append(scistats.pearsonr(full_count.ix[t], full_count.ix[not_in_T]))
#scistats.mannwhitneyu()

# %%
T

# %%
not_T

# %%
x = 'AABR07046248.1'
scistats.mannwhitneyu(T[x], not_T[x])

# %%
RGD = pd.read_csv('ftp://ftp.rgd.mcw.edu/pub/data_release/GENES_RAT.txt', sep='\t', skiprows=74)
RGD
# Out:
#        GENE_RGD_ID       SYMBOL  \
# 0          1595727     2463a1a2
# 1          1595726       2464a1
# 2          1595728     2461a1a2
# 3          1595729       2458a2
# 4          1594427    2331ex4-5
# 5          1594428    2310ex4-5
# 6          1594425    2361ex4-5
# 7          1594469       2509a1
# 8          1594457     2600a1a2
# 9          1594463     2539a1a2
# 10         1594461       2543a1
# 11         1594455     2609a1a2
# 12         1594451   2619a1_ps2
# 13         1594452   2619a1_ps1
# 14         1594450       2641a1
# 15         1594448     2646a1a2
# 16         1594443       2669a1
# 17         1594445       2664a1
# 18         1594446     2661a1a2
# 19         1594432       2715a1
# 20         1594431     2722a1a2
# 21         1594436       2702a1
# 22         1594438       2683a1
# 23         1594441     2673a1a2
# 24         1594435       2705a1
# 25         1594437  2690a1-a1a2
# 26         1597048       2781a1
# 27         1597057       2743a1
# 28         1597056     2747a1a2
# 29         1597055       2759a1
# ...            ...          ...
# 44976      1310745      Zscan10
# 44977       628738      Zscan12
# 44978      1560671      Zscan18
# 44979      1584548       Zscan2
# 44980      1562996      Zscan20
# 44981      1309981      Zscan21
# 44982       727885      Zscan26
# 44983      1559150      Zscan29
# 44984      1563625      Zscan4f
# 44985      1306095      Zscan30
# 44986      1559143      Zscan5b
# 44987      1305715       Zswim1
# 44988      1309789       Zswim3
# 44989      1311373       Zswim2
# 44990      1308020       Zswim4
# 44991      1310741       Zswim5
# 44992      1310324       Zswim7
# 44993      1306624       Zswim6
# 44994      1307672        Zufsp
# 44995      1309414       Zswim8
# 44996      1583880       Zwilch
# 44997      1309197         Zw10
# 44998      1563355         Zxdb
# 44999       628671        Zwint
# 45000      1561296         Zxdc
# 45001      1309582       Zyg11a
# 45002      1307814       Zyg11b
# 45003       620698          Zyx
# 45004      1311189        Zzef1
# 45005      1565468         Zzz3
#
#                                                     NAME  \
# 0                             class I gene fragment 2463
# 1                             class I gene fragment 2464
# 2                             class I gene fragment 2461
# 3                             class I gene fragment 2458
# 4                             class I gene fragment 2331
# 5                             class I gene fragment 2310
# 6                             class I gene fragment 2361
# 7                             class I gene fragment 2509
# 8                             class I gene fragment 2600
# 9                             class I gene fragment 2539
# 10                            class I gene fragment 2543
# 11                            class I gene fragment 2609
# 12              class I gene fragment 2619, pseudogene 2
# 13              class I gene fragment 2619, pseudogene 1
# 14                            class I gene fragment 2641
# 15                            class I gene fragment 2646
# 16                            class I gene fragment 2669
# 17                            class I gene fragment 2664
# 18                            class I gene fragment 2661
# 19                            class I gene fragment 2715
# 20                            class I gene fragment 2722
# 21                            class I gene fragment 2702
# 22                            class I gene fragment 2683
# 23                            class I gene fragment 2673
# 24                            class I gene fragment 2705
# 25                            class I gene fragment 2690
# 26                            class I gene fragment 2781
# 27                                           2743a1 gene
# 28                                   2747a1a2 pseudogene
# 29                                     2759a1 pseudogene
# ...                                                  ...
# 44976          zinc finger and SCAN domain containing 10
# 44977          zinc finger and SCAN domain containing 12
# 44978          zinc finger and SCAN domain containing 18
# 44979           zinc finger and SCAN domain containing 2
# 44980          zinc finger and SCAN domain containing 20
# 44981          zinc finger and SCAN domain containing 21
# 44982          zinc finger and SCAN domain containing 26
# 44983          zinc finger and SCAN domain containing 29
# 44984          zinc finger and SCAN domain containing 4F
# 44985          zinc finger and SCAN domain containing 30
# 44986          zinc finger and SCAN domain containing 5B
# 44987                zinc finger, SWIM-type containing 1
# 44988                zinc finger, SWIM-type containing 3
# 44989                zinc finger, SWIM-type containing 2
# 44990                zinc finger, SWIM-type containing 4
# 44991                zinc finger, SWIM-type containing 5
# 44992                zinc finger, SWIM-type containing 7
# 44993                zinc finger, SWIM-type containing 6
# 44994    zinc finger with UFM1-specific peptidase domain
# 44995                zinc finger, SWIM-type containing 8
# 44996                         zwilch kinetochore protein
# 44997                           zw10 kinetochore protein
# 44998                zinc finger, X-linked, duplicated B
# 44999               ZW10 interacting kinetochore protein
# 45000                           ZXD family zinc finger C
# 45001       zyg-11 family member A, cell cycle regulator
# 45002       zyg-11 family member B, cell cycle regulator
# 45003                                              zyxin
# 45004  zinc finger ZZ-type and EF-hand domain contain...
# 45005                  zinc finger, ZZ-type containing 3
#
#                                                GENE_DESC CHROMOSOME_CELERA  \
# 0                                                    NaN                20
# 1                                                    NaN                20
# 2                                                    NaN                20
# 3                                                    NaN                20
# 4                                                    NaN                20
# 5                                                    NaN                20
# 6                                                    NaN                20
# 7                                                    NaN               NaN
# 8                                                    NaN               NaN
# 9                                                    NaN               NaN
# 10                                                   NaN               NaN
# 11                                                   NaN               NaN
# 12                                                   NaN               NaN
# 13                                                   NaN               NaN
# 14                                                   NaN               NaN
# 15                                                   NaN               NaN
# 16                                                   NaN               NaN
# 17                                                   NaN               NaN
# 18                                                   NaN               NaN
# 19                                                   NaN               NaN
# 20                                                   NaN               NaN
# 21                                                   NaN               NaN
# 22                                                   NaN               NaN
# 23                                                   NaN               NaN
# 24                                                   NaN               NaN
# 25                                                   NaN               NaN
# 26                                                   NaN               NaN
# 27                                                   NaN               NaN
# 28                                                   NaN               NaN
# 29                                                   NaN               NaN
# ...                                                  ...               ...
# 44976  ENCODES a protein that exhibits sequence-speci...                10
# 44977  ENCODES a protein that exhibits metal ion bind...                17
# 44978  ENCODES a protein that exhibits metal ion bind...                 1
# 44979  ENCODES a protein that exhibits metal ion bind...                 1
# 44980  ENCODES a protein that exhibits metal ion bind...                 5
# 44981  ENCODES a protein that exhibits DNA binding (o...                12
# 44982  ENCODES a protein that exhibits metal ion bind...                17
# 44983  ENCODES a protein that exhibits metal ion bind...                 3
# 44984  ENCODES a protein that exhibits metal ion bind...               7;7
# 44985  ENCODES a protein that exhibits metal ion bind...                18
# 44986  INTERACTS WITH methapyrilene; aflatoxin B1 (or...                 1
# 44987  ENCODES a protein that exhibits zinc ion bindi...                 3
# 44988  ENCODES a protein that exhibits zinc ion bindi...                 3
# 44989  ENCODES a protein that exhibits protein self-a...                 3
# 44990  INTERACTS WITH bisphenol A; dibutyl phthalate;...                19
# 44991  FOUND IN extracellular space (ortholog); INTER...                 5
# 44992  ENCODES a protein that exhibits zinc ion bindi...                10
# 44993  INVOLVED IN neuron projection morphogenesis (o...                 2
# 44994  ENCODES a protein that exhibits metal ion bind...                20
# 44995  ENCODES a protein that exhibits zinc ion bindi...                15
# 44996  INVOLVED IN mitotic cell cycle checkpoint (ort...                 8
# 44997  INVOLVED IN ER to Golgi vesicle-mediated trans...                 8
# 44998  INTERACTS WITH bisphenol A; 1-fluoro-2,4-dinit...                 X
# 44999  ENCODES a protein that exhibits protein N-term...                20
# 45000  ENCODES a protein that exhibits C2H2 zinc fing...                 4
# 45001  INVOLVED IN protein ubiquitination (inferred);...                 5
# 45002  INVOLVED IN protein ubiquitination (inferred);...                 5
# 45003  ENCODES a protein that exhibits poly(A) RNA bi...                 4
# 45004  ENCODES a protein that exhibits calcium ion bi...                10
# 45005  ENCODES a protein that exhibits DNA binding (i...                 2
#
#       CHROMOSOME_3.1 CHROMOSOME_3.4 FISH_BAND   START_POS_CELERA  \
# 0                NaN             20       p12              43605
# 1                NaN             20       p12              42617
# 2                NaN             20       p12              45820
# 3                NaN             20       p12              49408
# 4                NaN             20       p12             150959
# 5                NaN             20       p12             171896
# 6                NaN             20       p12             171797
# 7                NaN             20       p12                NaN
# 8                NaN             20       p12                NaN
# 9                NaN             20       p12                NaN
# 10               NaN             20       NaN                NaN
# 11               NaN             20       p12                NaN
# 12               NaN             20       p12                NaN
# 13               NaN             20       p12                NaN
# 14               NaN             20       p12                NaN
# 15               NaN             20       p12                NaN
# 16               NaN             20       p12                NaN
# 17               NaN             20       p12                NaN
# 18               NaN             20       p12                NaN
# 19               NaN             20       p12                NaN
# 20               NaN             20       p12                NaN
# 21               NaN             20       p12                NaN
# 22               NaN             20       p12                NaN
# 23               NaN             20       p12                NaN
# 24               NaN             20       p12                NaN
# 25               NaN             20       p12                NaN
# 26               NaN             20       p12                NaN
# 27               NaN             20       p12                NaN
# 28               NaN             20       p12                NaN
# 29               NaN             20       p12                NaN
# ...              ...            ...       ...                ...
# 44976             10             10       q12           12332764
# 44977             17             17       p11           53214832
# 44978            NaN              1       q12           60409877
# 44979            NaN            NaN       q31          126887996
# 44980            NaN              5       q36          139413972
# 44981             12             12       q11           18928890
# 44982             17             17       p11           53299163
# 44983            NaN              3       q35          107034111
# 44984            NaN              7       q12  12673562;12622857
# 44985             18             18       p12           15199908
# 44986            NaN              1       q12           65408461
# 44987              3              3       q42          152165843
# 44988              3              3       q42          152150352
# 44989              3              3       q24           68365685
# 44990             19             19       q11           23476711
# 44991              5              5       q36          128873115
# 44992             10             10       q23           46203432
# 44993              2              2       q14           35056022
# 44994             20             20       q11           32202226
# 44995             15             15       p16            1004698
# 44996            NaN              8       q24           64045341
# 44997              8              8       q23           48953761
# 44998            NaN              X       q22           60194965
# 44999            NaN            NaN       p11           17366344
# 45000            NaN              4       q34          111806376
# 45001              5              5       q34          121672907
# 45002              5              5       q34          121725798
# 45003              4              4       q24           66168190
# 45004             10             10       q24           56538611
# 45005            NaN              2       q45          233291456
#
#          STOP_POS_CELERA    ...                                 ENSEMBL_ID  \
# 0                  44306    ...                                        NaN
# 1                  42831    ...                                        NaN
# 2                  46493    ...                                        NaN
# 3                  49623    ...                                        NaN
# 4                 151483    ...                                        NaN
# 5                 172245    ...                                        NaN
# 6                 172346    ...                                        NaN
# 7                    NaN    ...                                        NaN
# 8                    NaN    ...                                        NaN
# 9                    NaN    ...                                        NaN
# 10                   NaN    ...                                        NaN
# 11                   NaN    ...                                        NaN
# 12                   NaN    ...                                        NaN
# 13                   NaN    ...                                        NaN
# 14                   NaN    ...                                        NaN
# 15                   NaN    ...                                        NaN
# 16                   NaN    ...                                        NaN
# 17                   NaN    ...                                        NaN
# 18                   NaN    ...                                        NaN
# 19                   NaN    ...                                        NaN
# 20                   NaN    ...                                        NaN
# 21                   NaN    ...                                        NaN
# 22                   NaN    ...                                        NaN
# 23                   NaN    ...                                        NaN
# 24                   NaN    ...                                        NaN
# 25                   NaN    ...                                        NaN
# 26                   NaN    ...                                        NaN
# 27                   NaN    ...                                        NaN
# 28                   NaN    ...                                        NaN
# 29                   NaN    ...                                        NaN
# ...                  ...    ...                                        ...
# 44976           12342728    ...                         ENSRNOG00000021782
# 44977           53220733    ...                         ENSRNOG00000052959
# 44978           60481855    ...                         ENSRNOG00000026861
# 44979          126902196    ...                         ENSRNOG00000022164
# 44980          139442095    ...                         ENSRNOG00000005886
# 44981           18943650    ...                         ENSRNOG00000039234
# 44982           53320052    ...                         ENSRNOG00000053518
# 44983          107045528    ...                         ENSRNOG00000012419
# 44984  12677588;12626879    ...                         ENSRNOG00000028214
# 44985           15214437    ...                         ENSRNOG00000030131
# 44986           65416703    ...                         ENSRNOG00000049014
# 44987          152170425    ...                         ENSRNOG00000015735
# 44988          152165626    ...                         ENSRNOG00000015525
# 44989           68386070    ...                         ENSRNOG00000032579
# 44990           23501818    ...                         ENSRNOG00000007582
# 44991          128988373    ...                         ENSRNOG00000018160
# 44992           46215523    ...                         ENSRNOG00000002970
# 44993           35120828    ...                         ENSRNOG00000014528
# 44994           32232242    ...                         ENSRNOG00000000398
# 44995            1020476    ...      ENSRNOG00000009596;ENSRNOG00000056617
# 44996           64068910    ...                         ENSRNOG00000009303
# 44997           48978510    ...                         ENSRNOG00000054479
# 44998           60199202    ...                                        NaN
# 44999           17382150    ...                         ENSRNOG00000048682
# 45000          111838676    ...                         ENSRNOG00000025818
# 45001          121710606    ...                         ENSRNOG00000010885
# 45002          121780060    ...                         ENSRNOG00000010859
# 45003           66177032    ...                         ENSRNOG00000017354
# 45004           56675910    ...                         ENSRNOG00000024535
# 45005          233328678    ...                         ENSRNOG00000050321
#
#        GENE_REFSEQ_STATUS  CHROMOSOME_5.0 START_POS_5.0 STOP_POS_5.0  \
# 0                INFERRED              20       5196932      5197633
# 1                INFERRED              20       5195944      5196158
# 2                INFERRED              20       5199147      5199820
# 3                INFERRED              20       5202735      5202950
# 4                INFERRED              20       5330480      5331004
# 5                INFERRED              20       5351633      5351982
# 6                INFERRED              20       5297083      5297432
# 7                INFERRED              20       5160942      5161150
# 8                INFERRED              20         53977        54607
# 9                INFERRED             NaN           NaN          NaN
# 10               INFERRED              20       4623009      4623245
# 11               INFERRED             NaN           NaN          NaN
# 12               INFERRED             NaN           NaN          NaN
# 13               INFERRED              20       5080151      5080419
# 14               INFERRED             NaN           NaN          NaN
# 15               INFERRED             NaN           NaN          NaN
# 16               INFERRED             NaN           NaN          NaN
# 17               INFERRED             NaN           NaN          NaN
# 18               INFERRED              20       4702511      4702858
# 19               INFERRED             NaN           NaN          NaN
# 20               INFERRED             NaN           NaN          NaN
# 21               INFERRED             NaN           NaN          NaN
# 22               INFERRED             NaN           NaN          NaN
# 23               INFERRED             NaN           NaN          NaN
# 24               INFERRED             NaN           NaN          NaN
# 25               INFERRED             NaN           NaN          NaN
# 26               INFERRED             NaN           NaN          NaN
# 27               INFERRED              20       5111919      5112155
# 28               INFERRED             NaN           NaN          NaN
# 29               INFERRED              20       5111917      5112153
# ...                   ...             ...           ...          ...
# 44976         PROVISIONAL              10      12750768     12760736
# 44977               MODEL              17      58182624     58188509
# 44978               MODEL               1      66661602     66670021
# 44979               MODEL               1     143630849    143646301
# 44980               MODEL               5     150499839    150527856
# 44981           VALIDATED              12      21321339     21335687
# 44982               MODEL              17      58261028     58283803
# 44983                 NaN               3     119660192    119671580
# 44984               MODEL               7      18008166     18016817
# 44985               MODEL              18      15633119     15646180
# 44986               MODEL               1      72727880     72736122
# 44987               MODEL               3     167473504    167477750
# 44988         PROVISIONAL               3     167457669    167472951
# 44989         PROVISIONAL               3      77799741     77821020
# 44990         PROVISIONAL              19      36296871     36321982
# 44991         PROVISIONAL               5     139532215    139649659
# 44992           VALIDATED              10      48375622     48387713
# 44993               MODEL               2      58068503     58133311
# 44994         PROVISIONAL              20      34255576     34285599
# 44995           VALIDATED              15       3737336      3749884
# 44996               MODEL               8      68795665     68827635
# 44997         PROVISIONAL               8      51980064     52005883
# 44998               MODEL               X      64994855     65000186
# 44999         PROVISIONAL              20      19258272     19274238
# 45000               MODEL               4     186823155    186855265
# 45001               MODEL               5     131638763    131676983
# 45002               MODEL               5     131689475    131725322
# 45003           VALIDATED               4     136544775    136553784
# 45004               MODEL              10      59099067     59237547
# 45005           VALIDATED               2     276281516    276349781
#
#       STRAND_5.0 CHROMOSOME_6.0 START_POS_6.0 STOP_POS_6.0 STRAND_6.0
# 0              -             20       3098274      3098975          -
# 1              -             20       3097286      3097500          -
# 2              -             20       3100489      3101162          -
# 3              -             20       3104077      3104292          -
# 4              -             20       3232314      3232838          -
# 5              -             20       3253467      3253816          -
# 6              -             20       3198917      3199266          -
# 7              -             20       3062284      3062492          -
# 8              -             20         54530        55160          -
# 9            NaN            NaN           NaN          NaN        NaN
# 10             -            NaN           NaN          NaN        NaN
# 11           NaN            NaN           NaN          NaN        NaN
# 12           NaN            NaN           NaN          NaN        NaN
# 13             -             20       2982607      2982875          -
# 14           NaN            NaN           NaN          NaN        NaN
# 15           NaN            NaN           NaN          NaN        NaN
# 16           NaN            NaN           NaN          NaN        NaN
# 17           NaN            NaN           NaN          NaN        NaN
# 18             -             20       2600587      2600934          -
# 19           NaN            NaN           NaN          NaN        NaN
# 20           NaN            NaN           NaN          NaN        NaN
# 21           NaN            NaN           NaN          NaN        NaN
# 22           NaN            NaN           NaN          NaN        NaN
# 23           NaN            NaN           NaN          NaN        NaN
# 24           NaN            NaN           NaN          NaN        NaN
# 25           NaN            NaN           NaN          NaN        NaN
# 26           NaN            NaN           NaN          NaN        NaN
# 27             +             20       3013100      3013336          +
# 28           NaN            NaN           NaN          NaN        NaN
# 29             -             20       3013098      3013334          -
# ...          ...            ...           ...          ...        ...
# 44976          +             10      12929471     12939439          +
# 44977          +             17      45279171     45285069          -
# 44978          +              1      65845274     65858966          +
# 44979          +              1     142679308    142695232          +
# 44980          -              5     146760822    146788945          -
# 44981          +             12      19262977     19277913          +
# 44982          -             17      45188221     45207846          +
# 44983          -              3     113119729    113131148          -
# 44984          -              7      17852184     17860534          -
# 44985          -             18      15866470     15880569          -
# 44986          -              1      71334391     71342633          -
# 44987          +              3     161287884    161292466          +
# 44988          +              3     161272385    161287667          +
# 44989          -              3      71274341     71295641          -
# 44990          -             19      25320683     25345818          -
# 44991          +              5     135735825    135854525          +
# 44992          -             10      48587117     48599208          -
# 44993          -              2      38978042     39042886          -
# 44994          -             20      32471670     32501693          -
# 44995          -             15       4006470      4022238          -
# 44996          -              8      69089449     69121420          -
# 44997          +              8      53365881     53390742          +
# 44998          -              X      64092609     64097967          -
# 44999          -             20      17075781     17091715          -
# 45000          +              4     122282119    122314251          +
# 45001          -              5     127790162    127828911          -
# 45002          -              5     127844062    127878792          -
# 45003          +              4      71740188     71749386          +
# 45004          +             10      59360939     59498545          +
# 45005          +              2     257602924    257671783          +
#
# [45006 rows x 47 columns]
